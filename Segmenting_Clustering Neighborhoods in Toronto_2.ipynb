# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto -Coursera - Week3 - Part 2

# %% [markdown]
# ### Installing required libraries

# %%
import pandas as pd

# %% [markdown]
# #### Getting the geospatial Coordinates Data from https://cocl.us/Geospatial_data

# %%
# After getting the data, create the dataframe
url='https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv'
df_geo_spa=pd.read_csv(url)
df_geo_spa.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo_spa.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Update of first column's name to adjust it with dataframe of part 1

# %%
df_geo_spa = df_geo_spa.rename(columns = {'Postal Code':'PostalCode'}) 
df_geo_spa.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
#We upload the first dataset where we save it as csv file in part 1
df3=pd.read_csv('Clustering_part1.csv')
df3.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-a52b43178f2c> in <module>
#       1 #We upload the first dataset where we save it as csv file in part 1
# ----> 2 df3=pd.read_csv('\Clustering_part1.csv')
#       3 df3.head()
#
# ...
